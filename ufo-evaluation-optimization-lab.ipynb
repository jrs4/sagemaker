# %% [markdown]
# ## UFO Sightings Evaluation and Optimization Lab
#
# The goal of this notebook is to find out if our optimized model hyperparmeters out performs the training of our baseline Linear Learner model. We can also compare things like accurary and see if they differ.
#
# What we plan on accompishling is the following:
# 1. [Create and train our "optimized" model (Linear Learner)](#1.-Create-and-train-our-%22optimized%22-model-(Linear-Learner))
# 1. Compare the results!

# %% [markdown]
# First let's go ahead and import all the needed libraries.

# %%
import pandas as pd
import numpy as np
from datetime import datetime


import boto3
from sagemaker import get_execution_role
import sagemaker

# %%
role = get_execution_role()
bucket='sagemaker-js/DemoLabUFO'

# %% [markdown]
# ---
#
# ### 1. Create and train our "optimized" model (Linear Learner)
#
# Let's evaluate the Linear Learner algorithm with the new optimized hyperparameters. Let's go ahead and get the data that we already stored into S3 as recordIO protobuf data.

# %% [markdown]
# Let's get the recordIO file for the training data that is in S3

# %%
train_file = 'ufo_sightings_train_recordIO_protobuf.data'
training_recordIO_protobuf_location = 's3://{}/algorithms_lab/linearlearner_train/{}'.format(bucket, train_file)
print('The Pipe mode recordIO protobuf training data: {}'.format(training_recordIO_protobuf_location))
# Out:
# The Pipe mode recordIO protobuf training data: s3://sagemaker-js/DemoLabUFO/algorithms_lab/linearlearner_train/ufo_sightings_train_recordIO_protobuf.data

# %% [markdown]
# Let's get the recordIO file for the validation data that is in S3

# %%
validation_file = 'ufo_sightings_validatioin_recordIO_protobuf.data'
validate_recordIO_protobuf_location = 's3://{}/algorithms_lab/linearlearner_validation/{}'.format(bucket, validation_file)
print('The Pipe mode recordIO protobuf validation data: {}'.format(validate_recordIO_protobuf_location))
# Out:
# The Pipe mode recordIO protobuf validation data: s3://sagemaker-js/DemoLabUFO/algorithms_lab/linearlearner_validation/ufo_sightings_validatioin_recordIO_protobuf.data

# %% [markdown]
# ---
#
# Alright we are good to go for the Linear Learner algorithm. Let's get everything we need from the ECR repository to call the Linear Learner algorithm.

# %%
from sagemaker.amazon.amazon_estimator import get_image_uri
import sagemaker

container = get_image_uri(boto3.Session().region_name, 'linear-learner', "1")

# %% [markdown]
# Let's create a job and use the optimzed hyperparamters.

# %%
# Create a training job name
job_name = 'ufo-linear-learner-job-optimized-{}'.format(datetime.now().strftime("%Y%m%d%H%M%S"))
print('Here is the job name {}'.format(job_name))

# Here is where the model-artifact will be stored
output_location = 's3://{}/optimization_evaluation_lab/linearlearner_optimized_output'.format(bucket)
# Out:
# Here is the job name ufo-linear-learner-job-optimized-20190725131026

# %% [markdown]
# Next we can start building out our model by using the SageMaker Python SDK and passing in everything that is required to create a Linear Learner training job.
#
# Here are the [linear learner hyperparameters](https://docs.aws.amazon.com/sagemaker/latest/dg/ll_hyperparameters.html) that we can use within our training job.
#
# After we run this job we can view the results.

# %%
# %%time
sess = sagemaker.Session()

# Setup the LinearLeaner algorithm from the ECR container
linear = sagemaker.estimator.Estimator(container,
                                       role, 
                                       train_instance_count=1, 
                                       train_instance_type='ml.c4.xlarge',
                                       output_path=output_location,
                                       sagemaker_session=sess,
                                       input_mode='Pipe')
# Setup the hyperparameters
linear.set_hyperparameters( feature_dim=22, 
                            predictor_type='multiclass_classifier',
                            num_classes=3,
                            early_stopping_patience=3,
                            early_stopping_tolerance=0.001,
                            epochs=15,
                            l1=0.1333817642465768,
                            loss='auto',
                            mini_batch_size=692,
                            normalize_data='true',
                            normalize_label='auto',
                            num_models='auto',
                            optimizer='auto',
                            unbias_data='auto',
                            unbias_label='auto',
                            use_bias='true',
                            wd=0.008898628555711788
                          )


# Launch a training job. This method calls the CreateTrainingJob API call
data_channels = {
    'train': training_recordIO_protobuf_location,
    'validation': validate_recordIO_protobuf_location
}
linear.fit(data_channels, job_name=job_name)
# Out:
# 2019-06-26 13:36:13 Starting - Starting the training job...
# 2019-06-26 13:36:14 Starting - Launching requested ML instances......
# 2019-06-26 13:37:46 Starting - Preparing the instances for training.........
# 2019-06-26 13:39:12 Downloading - Downloading input data
# 2019-06-26 13:39:12 Training - Downloading the training image..
# Docker entrypoint called with argument(s): train
# [06/26/2019 13:39:28 INFO 139702039017280] Reading default configuration from /opt/amazon/lib/python2.7/site-packages/algorithm/resources/default-input.json: {u'loss_insensitivity': u'0.01', u'epochs': u'15', u'init_bias': u'0.0', u'lr_scheduler_factor': u'auto', u'num_calibration_samples': u'10000000', u'accuracy_top_k': u'3', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'num_point_for_scaler': u'10000', u'_log_level': u'info', u'quantile': u'0.5', u'bias_lr_mult': u'auto', u'lr_scheduler_step': u'auto', u'init_method': u'uniform', u'init_sigma': u'0.01', u'lr_scheduler_minimum_lr': u'auto', u'target_recall': u'0.8', u'num_models': u'auto', u'early_stopping_patience': u'3', u'momentum': u'auto', u'unbias_label': u'auto', u'wd': u'auto', u'optimizer': u'auto', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.001', u'learning_rate': u'auto', u'_kvstore': u'auto', u'normalize_data': u'true', u'binary_classifier_model_selection_criteria': u'accuracy', u'use_lr_scheduler': u'true', u'target_precision': u'0.8', u'unbias_data': u'auto', u'init_scale': u'0.07', u'bias_wd_mult': u'auto', u'f_beta': u'1.0', u'mini_batch_size': u'1000', u'huber_delta': u'1.0', u'num_classes': u'1', u'beta_1': u'auto', u'loss': u'auto', u'beta_2': u'auto', u'_enable_profiler': u'false', u'normalize_label': u'auto', u'_num_gpus': u'auto', u'balance_multiclass_weights': u'false', u'positive_example_weight_mult': u'1.0', u'l1': u'auto', u'margin': u'1.0'}
# [06/26/2019 13:39:28 INFO 139702039017280] Reading provided configuration from /opt/ml/input/config/hyperparameters.json: {u'loss': u'auto', u'wd': u'0.008898628555711788', u'optimizer': u'auto', u'predictor_type': u'multiclass_classifier', u'unbias_label': u'auto', u'early_stopping_tolerance': u'0.001', u'num_models': u'auto', u'normalize_data': u'true', u'epochs': u'15', u'normalize_label': u'auto', u'feature_dim': u'22', u'unbias_data': u'auto', u'l1': u'0.1333817642465768', u'mini_batch_size': u'692', u'use_bias': u'true', u'early_stopping_patience': u'3', u'num_classes': u'3'}
# [06/26/2019 13:39:28 INFO 139702039017280] Final configuration: {u'loss_insensitivity': u'0.01', u'epochs': u'15', u'feature_dim': u'22', u'init_bias': u'0.0', u'lr_scheduler_factor': u'auto', u'num_calibration_samples': u'10000000', u'accuracy_top_k': u'3', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'num_point_for_scaler': u'10000', u'_log_level': u'info', u'quantile': u'0.5', u'bias_lr_mult': u'auto', u'lr_scheduler_step': u'auto', u'init_method': u'uniform', u'init_sigma': u'0.01', u'lr_scheduler_minimum_lr': u'auto', u'target_recall': u'0.8', u'num_models': u'auto', u'early_stopping_patience': u'3', u'momentum': u'auto', u'unbias_label': u'auto', u'wd': u'0.008898628555711788', u'optimizer': u'auto', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.001', u'learning_rate': u'auto', u'_kvstore': u'auto', u'normalize_data': u'true', u'binary_classifier_model_selection_criteria': u'accuracy', u'use_lr_scheduler': u'true', u'target_precision': u'0.8', u'unbias_data': u'auto', u'init_scale': u'0.07', u'bias_wd_mult': u'auto', u'f_beta': u'1.0', u'mini_batch_size': u'692', u'huber_delta': u'1.0', u'num_classes': u'3', u'predictor_type': u'multiclass_classifier', u'beta_1': u'auto', u'loss': u'auto', u'beta_2': u'auto', u'_enable_profiler': u'false', u'normalize_label': u'auto', u'_num_gpus': u'auto', u'balance_multiclass_weights': u'false', u'positive_example_weight_mult': u'1.0', u'l1': u'0.1333817642465768', u'margin': u'1.0'}
# [06/26/2019 13:39:28 WARNING 139702039017280] Loggers have already been setup.
# Process 1 is a worker.
# [06/26/2019 13:39:28 INFO 139702039017280] Using default worker.
# [06/26/2019 13:39:28 INFO 139702039017280] The channel 'train' is in pipe input mode under /opt/ml/input/data/train.
# [06/26/2019 13:39:28 INFO 139702039017280] The channel 'validation' is in pipe input mode under /opt/ml/input/data/validation.
# [2019-06-26 13:39:28.792] [tensorio] [warning] TensorIO is already initialized; ignoring the initialization routine.
# [2019-06-26 13:39:28.826] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 0, "duration": 38, "num_examples": 1, "num_bytes": 91344}
# [06/26/2019 13:39:28 INFO 139702039017280] Create Store: local
# [2019-06-26 13:39:28.970] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 1, "duration": 143, "num_examples": 15, "num_bytes": 1370160}
# [06/26/2019 13:39:28 INFO 139702039017280] Scaler algorithm parameters
#  <algorithm.scaler.ScalerAlgorithmStable object at 0x7f0e99163f50>
# [06/26/2019 13:39:28 INFO 139702039017280] Scaling model computed with parameters:
#  {'stdev_weight':
# [28.758474    2.877447    9.904637   38.46429     0.35688245  0.26958534
#   0.38254198  0.32148227  0.3763422   0.35904333  0.3497444   0.32056195
#   0.32857653  0.10777398  0.4727161   0.46984926  0.29426333  0.10285567
#   0.09911843  0.23282298  0.28739253  0.2326398 ]
# <NDArray 22 @cpu(0)>, 'stdev_label': None, 'mean_label': None, 'mean_weight':
# [
"Dimensions": {"model": 13, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1561556369.891196}
#
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 0.30149489745405256, "sum": 0.30149489745405256, "min": 0.30149489745405256}}, "EndTime": 1561556369.891273, "Dimensions": {"model": 14, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1561556369.891255}
#
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 0.5995496651982427, "sum": 0.5995496651982427, "min": 0.5995496651982427}}, "EndTime": 1561556369.891343, "Dimensions": {"model": 15, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1561556369.891324}
#
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 0.5810703421741708, "sum": 0.5810703421741708, "min": 0.5810703421741708}}, "EndTime": 1561556369.891413, "Dimensions": {"model": 16, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1561556369.891395}
#
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 0.9435273163478656, "sum": 0.9435273163478656, "min": 0.9435273163478656}}, "EndTime": 1561556369.891481, "Dimensions": {"model": 17, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1561556369.891464}
#
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 0.24782350543388457, "sum": 0.24782350543388457, "min": 0.24782350543388457}}, "EndTime": 1561556369.891533, "Dimensions": {"model": 18, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1561556369.891522}
#
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 0.29915116294520894, "sum": 0.29915116294520894, "min": 0.29915116294520894}}, "EndTime": 1561556369.891569, "Dimensions": {"model": 19, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1561556369.891556}
#
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 0.26544788444506134, "sum": 0.26544788444506134, "min": 0.26544788444506134}}, "EndTime": 1561556369.891625, "Dimensions": {"model": 20, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1561556369.89161}
#
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 0.3496061907067382, "sum": 0.3496061907067382, "min": 0.3496061907067382}}, "EndTime": 1561556369.89169, "Dimensions": {"model": 21, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1561556369.891673}
#
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 0.2645980783323749, "sum": 0.2645980783323749, "min": 0.2645980783323749}}, "EndTime": 1561556369.891752, "Dimensions": {"model": 22, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1561556369.891735}
#
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 0.26804192161667634, "sum": 0.26804192161667634, "min": 0.26804192161667634}}, "EndTime": 1561556369.891804, "Dimensions": {"model": 23, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1561556369.891788}
#
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 0.3082471138598619, "sum": 0.3082471138598619, "min": 0.3082471138598619}}, "EndTime": 1561556369.891861, "Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1561556369.891844}
#
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 0.5379767248473192, "sum": 0.5379767248473192, "min": 0.5379767248473192}}, "EndTime": 1561556369.891938, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1561556369.891902}
#
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 0.24931164616188356, "sum": 0.24931164616188356, "min": 0.24931164616188356}}, "EndTime": 1561556369.892006, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1561556369.891988}
#
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 0.8423157254653131, "sum": 0.8423157254653131, "min": 0.8423157254653131}}, "EndTime": 1561556369.892062, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1561556369.892046}
#
# [06/26/2019 13:39:29 INFO 139702039017280] #quality_metric: host=algo-1, epoch=0, validation multiclass_cross_entropy_objective <loss>=0.284358735146
# [06/26/2019 13:39:29 INFO 139702039017280] #early_stopping_criteria_metric: host=algo-1, epoch=0, criteria=multiclass_cross_entropy_objective, value=0.247234359543
# [06/26/2019 13:39:29 INFO 139702039017280] Epoch 0: Loss improved. Updating best model
# [06/26/2019 13:39:29 INFO 139702039017280] #progress_metric: host=algo-1, completed 6 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 21, "sum": 21.0, "min": 21}, "Number of Batches Since Last Reset": {"count": 1, "max": 21, "sum": 21.0, "min": 21}, "Number of Records Since Last Reset": {"count": 1, "max": 14430, "sum": 14430.0, "min": 14430}, "Total Batches Seen": {"count": 1, "max": 37, "sum": 37.0, "min": 37}, "Total Records Seen": {"count": 1, "max": 25502, "sum": 25502.0, "min": 25502}, "Max Records Seen Between Resets": {"count": 1, "max": 14430, "sum": 14430.0, "min": 14430}, "Reset Count": {"count": 1, "max": 3, "sum": 3.0, "min": 3}}, "EndTime": 1561556369.893586, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1561556369.147581}
#
# [06/26/2019 13:39:29 INFO 139702039017280] #throughput_metric: host=algo-1, train throughput=19339.509334 records/second
# [2019-06-26 13:39:30.460] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 5, "duration": 566, "num_examples": 21, "num_bytes": 1904760}
# #metrics {"Metrics": {"train_multiclass_cross_entropy_objective": {"count": 1, "max": 0.2153131821252018, "sum": 0.2153131821252018, "min": 0.2153131821252018}}, "EndTime": 1561556370.461017, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1561556370.460939}
#
# #metrics {"Metrics": {"train_multiclass_cross_entropy_objective": {"count": 1, "max": 0.259388834341413, "sum": 0.259388834341413, "min": 0.259388834341413}}, "EndTime": 1561556370.461094, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 1}, "StartTime": 1561556370.46108}
#
# #metrics {"Metrics": {"train_multiclass_cross_entropy_objective": {"count": 1, "max": 0
"Dimensions": {"model": 15, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 5}, "StartTime": 1561556373.617236}
#
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 0.2570490785997867, "sum": 0.2570490785997867, "min": 0.2570490785997867}}, "EndTime": 1561556373.617296, "Dimensions": {"model": 16, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 5}, "StartTime": 1561556373.617284}
#
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 0.5533207152700667, "sum": 0.5533207152700667, "min": 0.5533207152700667}}, "EndTime": 1561556373.617343, "Dimensions": {"model": 17, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 5}, "StartTime": 1561556373.61733}
#
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 0.26655613038073267, "sum": 0.26655613038073267, "min": 0.26655613038073267}}, "EndTime": 1561556373.61739, "Dimensions": {"model": 18, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 5}, "StartTime": 1561556373.617377}
#
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 0.2988436419750026, "sum": 0.2988436419750026, "min": 0.2988436419750026}}, "EndTime": 1561556373.617437, "Dimensions": {"model": 19, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 5}, "StartTime": 1561556373.617424}
#
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 0.24277853064797925, "sum": 0.24277853064797925, "min": 0.24277853064797925}}, "EndTime": 1561556373.617483, "Dimensions": {"model": 20, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 5}, "StartTime": 1561556373.61747}
#
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 0.29998236245780896, "sum": 0.29998236245780896, "min": 0.29998236245780896}}, "EndTime": 1561556373.617529, "Dimensions": {"model": 21, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 5}, "StartTime": 1561556373.617516}
#
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 0.23982711680111612, "sum": 0.23982711680111612, "min": 0.23982711680111612}}, "EndTime": 1561556373.617584, "Dimensions": {"model": 22, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 5}, "StartTime": 1561556373.61757}
#
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 0.23549994195980065, "sum": 0.23549994195980065, "min": 0.23549994195980065}}, "EndTime": 1561556373.617635, "Dimensions": {"model": 23, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 5}, "StartTime": 1561556373.617622}
#
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 0.2349062003594499, "sum": 0.2349062003594499, "min": 0.2349062003594499}}, "EndTime": 1561556373.61769, "Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 5}, "StartTime": 1561556373.617677}
#
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 0.24540114900316817, "sum": 0.24540114900316817, "min": 0.24540114900316817}}, "EndTime": 1561556373.617746, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 5}, "StartTime": 1561556373.617733}
#
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 0.2328539922018207, "sum": 0.2328539922018207, "min": 0.2328539922018207}}, "EndTime": 1561556373.617795, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 5}, "StartTime": 1561556373.617782}
#
# #metrics {"Metrics": {"validation_multiclass_cross_entropy_objective": {"count": 1, "max": 0.38646409260103814, "sum": 0.38646409260103814, "min": 0.38646409260103814}}, "EndTime": 1561556373.617841, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 5}, "StartTime": 1561556373.617828}
#
# [06/26/2019 13:39:33 INFO 139702039017280] #quality_metric: host=algo-1, epoch=5, validation multiclass_cross_entropy_objective <loss>=0.230357687015
# [06/26/2019 13:39:33 INFO 139702039017280] #early_stopping_criteria_metric: host=algo-1, epoch=5, criteria=multiclass_cross_entropy_objective, value=0.230357687015
# [06/26/2019 13:39:33 INFO 139702039017280] Early stop condition met. Stopping training.
# [06/26/2019 13:39:33 INFO 139702039017280] #progress_metric: host=algo-1, completed 100 % epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 21, "sum": 21.0, "min": 21}, "Number of Batches Since Last Reset": {"count": 1, "max": 21, "sum": 21.0, "min": 21}, "Number of Records Since Last Reset": {"count": 1, "max": 14430, "sum": 14430.0, "min": 14430}, "Total Batches Seen": {"count": 1, "max": 142, "sum": 142.0, "min": 142}, "Total Records Seen": {"count": 1, "max": 97652, "sum": 97652.0, "min": 97652}, "Max Records Seen Between Resets": {"count": 1, "max": 14430, "sum": 14430.0, "min": 14430}, "Reset Count": {"count": 1, "max": 8, "sum": 8.0, "min": 8}}, "EndTime": 1561556373.618924, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 5}, "StartTime": 1561556372.952494}
#
# [06/26/2019 13:39:33 INFO 139702039017280] #throughput_metric: host=algo-1, train throughput=21648.4968511 records/second
# [06/26/2019 13:39:33 WARNING 139702039017280] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [06/26/2019 13:39:33 WARNING 139702039017280] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [2019-06-26 13:39:33.706] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/validation", "epoch": 20, "duration": 64, "num_examples": 3, "num_bytes": 234036}
# [06/26/2019 13:39:33 INFO 139702039017280] #early_stopping_criteria_metric: host=algo-1, epoch=5, criteria=multiclass_cross_entropy_objective, value=0.230357687015
# [2019-06-26 13:39:33.753] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/validation", "epoch": 22, "duration": 35, "num_examples": 3, "num_bytes": 234036}
# [06/26/2019 13:39:33 INFO 139702039017280] #validation_score (algo-1) : ('multiclass_cross_entropy_objective', 0.2300623309054216)
# [06/26/2019 13:39:33 INFO 139702039017280] #validation_score (algo-1) : ('multiclass_accuracy', 0.9317540891144952)
# [06/26/2019 13:39:33 INFO 139702039017280] #validation_score (algo-1) : ('multiclass_top_k_accuracy_3', 1.0)
# [06/26/2019 13:39:33 INFO 139702039017280] #validation_score (algo-1) : ('dcg', 0.9728186145315585)
# [06/26/2019 13:39:33 INFO 139702039017280] #validation_score (algo-1) : ('macro_recall', 0.9132151)
# [06/26/2019 13:39:33 INFO 139702039017280] #validation_score (algo-1) : ('macro_precision', 0.8731456)
# [06/26/2019 13:39:33 INFO 139702039017280] #validation_score (algo-1) : ('macro_f_1.000', 0.8907816)
# [06/26/2019 13:39:33 INFO 139702039017280] #quality_metric: host=algo-1, validation multiclass_cross_entropy_objective <loss>=0.230062330905
# [06/26/2019 13:39:33 INFO 139702039017280] #quality_metric: host=algo-1, validation multiclass_accuracy <score>=0.931754089114
# [06/26/2019 13:39:33 INFO 139702039017280] #quality_metric: host=algo-1, validation multiclass_top_k_accuracy_3 <score>=1.0
# [06/26/2019 13:39:33 INFO 139702039017280] #quality_metric: host=algo-1, validation dcg <score>=0.972818614532
# [06/26/2019 13:39:33 INFO 139702039017280] #quality_metric: host=algo-1, validation macro_recall <score>=0.913215100765
# [06/26/2019 13:39:33 INFO 139702039017280] #quality_metric: host=algo-1, validation macro_precision <score>=0.873145580292
# [06/26/2019 13:39:33 INFO 139702039017280] #quality_metric: host=algo-1, validation macro_f_1.000 <score>=0.890781581402
# [06/26/2019 13:39:33 INFO 139702039017280] Best model found for hyperparameters: {"lr_scheduler_step": 243, "wd": 0.022269995381740192, "optimizer": "adam", "lr_scheduler_factor": 0.9831300246895756, "l1": 0.0799911067820927, "learning_rate": 0.030664730174005284, "lr_scheduler_minimum_lr": 9.042943346173945e-05}
# [06/26/2019 13:39:33 INFO 139702039017280] Saved checkpoint to "/tmp/tmpihLoj7/mx-mod-0000.params"
# [06/26/2019 13:39:33 INFO 139702039017280] Test data is not provided.
# #metrics {"Metrics": {"totaltime": {"count": 1, "max": 5090.342998504639, "sum": 5090.342998504639, "min": 5090.342998504639}, "finalize.time": {"count": 1, "max": 151.26299858093262, "sum": 151.26299858093262, "min": 151.26299858093262}, "initialize.time": {"count": 1, "max": 343.0368900299072, "sum": 343.0368900299072, "min": 343.0368900299072}, "check_early_stopping.time": {"count": 7, "max": 1.0960102081298828, "sum": 3.075838088989258, "min": 0.21886825561523438}, "setuptime": {"count": 1, "max": 30.42292594909668, "sum": 30.42292594909668, "min": 30.42292594909668}, "update.time": {"count": 6, "max": 825.0248432159424, "sum": 4468.432664871216, "min": 666.1598682403564}, "epochs": {"count": 1, "max": 15, "sum": 15.0, "min": 15}}, "EndTime": 1561556373.782518, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner"}, "StartTime": 1561556368.78735}
# 2019-06-26 13:39:42 Uploading - Uploading generated training model
# 2019-06-26 13:39:42 Completed - Training job completed
# Billable seconds: 47
# CPU times: user 562 ms, sys: 13 ms, total: 575 ms
# Wall time: 3min 48s

# %% [markdown]
# Now we can compare the amount of time billed and the accuracy compared to our baseline model.
